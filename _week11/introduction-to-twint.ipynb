# %% [markdown]
# # Scraping Twitter with `twint`
#
# `twint` is a Python library for scraping tweets. It can be used either on the command line or in a Python script. For full documentation, I recommend checking out the full wiki for the documentation:https://github.com/twintproject/twint/wiki/
#
# For `twint` variables, see: https://github.com/twintproject/twint/wiki/Configuration
#
# NOTE: You may need to take a break if you're peforming   250 items

# %%
# !pip install --upgrade pip

# %%
# !pip install nest_asyncio

# %%
# !pip3 install twint

# %%
# !pip3 install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint

# %% [markdown]
# ### NOTE
# Once you installed and upgraded twint, you may need to restart your kernel. Click on the "Kernel" button in the top menu, and then select "Restart Kernel." Restarting the kernel will still save any installations you've performed (but will clear variables or other commands).

# %%
# Import libraries
import nest_asyncio
import twint

# %%
nest_asyncio.apply()
# Configure
c = twint.Config()
# Let's look at the tweets of Jorts the Cat
c.Username = "JortsTheCat"
# Let's search for all tweets that contain the string 'paw'
c.Search = "paw"
c.Limit = 10
c.Since = "2022-01-27"
# Save our output as a CSV file
c.Output = "./jorts-paw-tweets.csv"
c.Store_csv = True


# Run
twint.run.Search(c)
# Out:
# 1589577998575239168 2022-11-07 06:18:22 -0500 <JortsTheCat> Wow there are smudgy paw prints on your monitor? I’ll keep my eye out for a guy with paws  https://t.co/629Lxb7xwq
# 1587260619488575488 2022-10-31 21:49:56 -0500 <JortsTheCat> Seasonal reminder: Paw Patrol is copaganda
# 1585872629403045889 2022-10-28 01:54:33 -0500 <JortsTheCat> If you’re getting mauled, check if there was a paw print on our app!
# 1585758728426426368 2022-10-27 18:21:57 -0500 <JortsTheCat> 4 steps (one for each paw)
# 1568481751810605058 2022-09-10 02:09:25 -0500 <JortsTheCat> @spiderandme @paulbrislen There has to be a space between “it’s not even real” and “overrated” and I guess that space is paw paw sized
# 1568478416944627713 2022-09-10 01:56:10 -0500 <JortsTheCat> Are paw paw fruits real or is that just a joke
# 1560133959853281280 2022-08-18 01:18:16 -0500 <JortsTheCat> The softest paw can be a claw
# ...

# %% [markdown]
# ## NOTE:
# See my above comment: When running multiple twint searches, you may need to pause between them, or restart your kernel.

# %% [markdown]
# ## Let's look at the dataset we created
# We ouput our tweets to a csv file called "jorts-paw-tweets.csv". Let's take a look at it

# %%
import pandas as pd

# %%
jorts_df = pd.read_csv('jorts-paw-tweets.csv', encoding='utf-8')
jorts_df
# Out:
#                      id      conversation_id               created_at  \
# 0   1589577998575239168  1589577998575239168  2022-11-07 06:18:22 EST
# 1   1587260619488575488  1587260619488575488  2022-10-31 21:49:56 EDT
# 2   1585872629403045889  1585872629403045889  2022-10-28 01:54:33 EDT
# 3   1585758728426426368  1585758728426426368  2022-10-27 18:21:57 EDT
# 4   1568481751810605058  1568478416944627713  2022-09-10 02:09:25 EDT
# 5   1568478416944627713  1568478416944627713  2022-09-10 01:56:10 EDT
# 6   1560133959853281280  1560133959853281280  2022-08-18 01:18:16 EDT
# 7   1559777375298039809  1559422551545335809  2022-08-17 01:41:20 EDT
# 8   1553132265982439424  1553132265982439424  2022-07-29 17:36:02 EDT
# 9   1543817625519525888  1540228232607240192  2022-07-04 00:42:59 EDT
# 10  1537939995175989248  1537939995175989248  2022-06-17 19:27:23 EDT
# 11  1530993243504070656  1530993243504070656  2022-05-29 15:23:28 EDT
# ...
